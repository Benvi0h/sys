# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import *
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import tree

# %%
data = pd.read_csv("pima.csv")

# %%
X = data.drop("Outcome", axis=1)
y = data["Outcome"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.20)

# %%
model1 = RandomForestClassifier()
model2 = DecisionTreeClassifier()
model3 = DecisionTreeClassifier(max_depth=3)

# %%
model1.fit(X_train,y_train)
model2.fit(X_train,y_train)
model3.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
y_pred1 = model1.predict(X_test)
y_pred2 = model2.predict(X_test)
y_pred3 = model3.predict(X_test)

# %%
print("Accuracy of Random Forest",accuracy_score(y_test,y_pred1))
print("Accuracy of Decison Tree",accuracy_score(y_test,y_pred2))
# Out:
# Accuracy of Random Forest 0.7337662337662337
# Accuracy of Decison Tree 0.6753246753246753

# %%
cols = list(data.columns)

# %%
plt.figure(figsize=(25, 20))
tree.plot_tree(model1[0], feature_names=cols, class_names = ["0","1"],filled=True)
# Out:
# [Text(0.594535175879397, 0.9666666666666667, 'SkinThickness <= 30.5\ngini = 0.467\nsamples = 396\nvalue = [386, 228]\nclass = 0'),
#  Text(0.3712311557788945, 0.9, 'BloodPressure <= 99.0\ngini = 0.402\nsamples = 273\nvalue = [297, 115]\nclass = 0'),
#  Text(0.35113065326633164, 0.8333333333333334, 'Insulin <= 446.5\ngini = 0.388\nsamples = 268\nvalue = [296, 106]\nclass = 0'),
#  Text(0.34108040201005024, 0.7666666666666667, 'DiabetesPedigreeFunction <= 0.509\ngini = 0.372\nsamples = 263\nvalue = [296, 97]\nclass = 0'),
#  Text(0.20854271356783918, 0.7, 'Insulin <= 7.5\ngini = 0.287\nsamples = 173\nvalue = [219, 46]\nclass = 0'),
#  Text(0.12814070351758794, 0.6333333333333333, 'Age <= 41.5\ngini = 0.348\nsamples = 103\nvalue = [121, 35]\nclass = 0'),
#  Text(0.09045226130653267, 0.5666666666666667, 'DiabetesPedigreeFunction <= 0.477\ngini = 0.225\nsamples = 76\nvalue = [101, 15]\nclass = 0'),
# ...

# %%
plt.figure(figsize=(20, 20))
tree.plot_tree(model2, feature_names=cols, filled=True)
# Out:
# [Text(0.5010729613733905, 0.9615384615384616, 'Glucose <= 127.5\ngini = 0.454\nsamples = 614\nvalue = [400, 214]'),
#  Text(0.26126609442060084, 0.8846153846153846, 'Age <= 30.5\ngini = 0.313\nsamples = 397\nvalue = [320, 77]'),
#  Text(0.1453862660944206, 0.8076923076923077, 'BMI <= 45.4\ngini = 0.179\nsamples = 252\nvalue = [227, 25]'),
#  Text(0.10622317596566523, 0.7307692307692307, 'DiabetesPedigreeFunction <= 0.501\ngini = 0.162\nsamples = 248\nvalue = [226, 22]'),
#  Text(0.0536480686695279, 0.6538461538461539, 'Pregnancies <= 6.5\ngini = 0.079\nsamples = 169\nvalue = [162, 7]'),
#  Text(0.03648068669527897, 0.5769230769230769, 'BMI <= 29.45\ngini = 0.059\nsamples = 165\nvalue = [160, 5]'),
#  Text(0.027896995708154508, 0.5, 'gini = 0.0\nsamples = 87\nvalue = [87, 0]'),
#  Text(0.045064377682403435, 0.5, 'BMI <= 29.8\ngini = 0.12\nsamples = 78\nvalue = [73, 5]'),
#  Text(0.017167381974248927, 0.4230769230769231, 'Pregnancies <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
# ...

# %%
plt.figure(figsize = (20, 20))
tree.plot_tree(model3, feature_names = cols, filled = True)
# Out:
# [Text(0.5, 0.875, 'Glucose <= 127.5\ngini = 0.454\nsamples = 614\nvalue = [400, 214]'),
#  Text(0.25, 0.625, 'Age <= 30.5\ngini = 0.313\nsamples = 397\nvalue = [320, 77]'),
#  Text(0.125, 0.375, 'BMI <= 45.4\ngini = 0.179\nsamples = 252\nvalue = [227, 25]'),
#  Text(0.0625, 0.125, 'gini = 0.162\nsamples = 248\nvalue = [226, 22]'),
#  Text(0.1875, 0.125, 'gini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.375, 0.375, 'BMI <= 26.95\ngini = 0.46\nsamples = 145\nvalue = [93, 52]'),
#  Text(0.3125, 0.125, 'gini = 0.069\nsamples = 28\nvalue = [27, 1]'),
#  Text(0.4375, 0.125, 'gini = 0.492\nsamples = 117\nvalue = [66, 51]'),
#  Text(0.75, 0.625, 'BMI <= 29.95\ngini = 0.466\nsamples = 217\nvalue = [80, 137]'),
#  Text(0.625, 0.375, 'Glucose <= 145.0\ngini = 0.433\nsamples = 63\nvalue = [43, 20]'),
#  Text(0.5625, 0.125, 'gini = 0.272\nsamples = 37\nvalue = [31, 6]'),
#  Text(0.6875, 0.125, 'gini = 0.497\nsamples = 26\nvalue = [12, 14]'),
# ...
